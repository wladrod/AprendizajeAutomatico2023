# %% [markdown]
# <center>
# <a href="https://colab.research.google.com/github/wladrod/AprendizajeAutomatico2023/blob/master/notebooks/03-TutorialPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# </center>

# %% [markdown]
# <center>
#     <h1>Introducción a Pandas</h1>
#     <br/>
#     <img src='../figuras/pandas.svg'/>
#     </center>

# %% [markdown]
# Definitivamente es el sinónimo de "Python para el análisis de datos".
#
# [Pandas](https://pandas.pydata.org/index.html) es una poderosa librería de Python de análisis de datos que se construye encima de numpy que es otra librería que le permite crear arreglos de datos 2d e incluso 3d en Python. El objeto principal de pandas se llama un `DataFrame`. Un `DataFrame` es básicamente una matriz numpy de 2d con filas y columnas, que también tiene etiquetas para columnas y filas.
#
# Pandas ofrece las siguientes estructuras de datos:
#
# *Series*: Son arrays unidimensionales con indexación (arrays con índice o etiquetados), similar a los diccionarios. Pueden generarse a partir de diccionarios o de listas.
#
# *DataFrame*: Son estructuras de datos similares a las tablas de bases de datos relacionales como SQL.
#
# Puede crear `DataFrames` de varios formatos de datos de entrada, como CSV, JSON, diccionarios Python, etc. Una vez que haya cargado el marco de datos en Python, puede aplicar varias funciones de análisis y visualización de datos al `DataFrame` y convertir básicamente los datos del `DataFrame` en información valiosa.

# %% [markdown]
# El primer ejemplo que vamos a poner va a ser el de definir una estructura de datos "Series" que como ya comentamos es un array de datos unidimensional con idexación. Las "Series" se definen de la siguiente manera:
#
#     serie = pd.Series(data, index=index)

# %% [markdown]
# Es decir, que en el primer parámetro le indicamos los datos del array y en el segundo parámetro los índices. Veamos un ejemplo de como crear una estructura "Series" con los integrantes de la selección Española de fútbol que ganó el mudial del año 2010, en el que tenemos como 'data' sus nombres y como índice su dorsal:

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.__version__
# Out:
# '2.0.3'

# %%
seleccionEspaña = pd.Series(
    ['Casillas', 'Ramos', 'Pique', 'Puyol', 'Capdevila', 'Xabi Alonso', 'Busquets', 'Xavi Hernandez', 'Pedrito',
     'Iniesta', 'Villa'], index=[1, 15, 3, 5, 11, 14, 16, 8, 18, 6, 7])
print ("Jugadores de la Selección Española: \n%s" % seleccionEspaña)
# Out:
# Jugadores de la Selección Española:
# 1           Casillas
# 15             Ramos
# 3              Pique
# 5              Puyol
# 11         Capdevila
# 14       Xabi Alonso
# 16          Busquets
# 8     Xavi Hernandez
# 18           Pedrito
# 6            Iniesta
# 7              Villa
# dtype: object

# %% [markdown]
# En el siguiente caso; en el que no le indiquemos los índices de forma explícita, no generará los índices de forma automática empezando desde el valor cero:

# %%
seleccionEspaña = pd.Series(
    ['Casillas', 'Ramos', 'Pique', 'Puyol', 'Capdevila', 'Xabi Alonso', 'Busquets', 'Xavi Hernandez', 'Pedrito',
     'Iniesta', 'Villa'])
print ("Jugadores de la Selección Española: \n%s" % seleccionEspaña)
# Out:
# Jugadores de la Selección Española:
# 0           Casillas
# 1              Ramos
# 2              Pique
# 3              Puyol
# 4          Capdevila
# 5        Xabi Alonso
# 6           Busquets
# 7     Xavi Hernandez
# 8            Pedrito
# 9            Iniesta
# 10             Villa
# dtype: object

# %% [markdown]
# También podemos crearnos una estructura de datos "Series" a partir de una lista o de un diccionario. Si la construimos a partir de una lista nos pondrá los índices por defecto y si lo creamos a partir de un diccionario, pondrá como índices las claves. Vamos a ver a continuación un ejemplo de como crear una Serie a partir de un diccionario y además vamos a ver como insertar en esta serie un nuevo elemento:

# %%
dictJugadores = {1: 'Casillas', 15: 'Ramos', 3: 'Pique', 5: 'Puyol', 11: 'Capdevila', 14: 'Xabi Alonso',
               16: 'Busquets', 8: 'Xavi Hernandez', 18: 'Pedrito', 6: 'Iniesta', 7: 'Villa'}
jugadores = pd.Series(dictJugadores)
# Insertar un nuevo jugador
jugadores[10] = 'Cesc'
print ("Jugadores de la Selección de Futbol Española: \n\n%s" % jugadores)
# Out:
# Jugadores de la Selección de Futbol Española:
#
# 1           Casillas
# 15             Ramos
# 3              Pique
# 5              Puyol
# 11         Capdevila
# 14       Xabi Alonso
# 16          Busquets
# 8     Xavi Hernandez
# 18           Pedrito
# 6            Iniesta
# 7              Villa
# 10              Cesc
# dtype: object

# %% [markdown]
# Vamos a pasar a continuación a ver un ejemplo con la estructura de datos `DataFrame`. Como ya se ha comentado es una estructura de datos similar a una tabla de una base de datos relacionar, una tabla de excel, etc. y como tal se pueden hacer muchas operaciones como las que se harían con consultas a tablas de bases de datos o en excel.
#
# Para construir un `DataFrame` se puede hacer de diferentes formas, como por ejemplo a partir de una lista, de un diccionario, de una Serie, de otro `DataFrame`, leyendo una tabla excel, csv, etc. Vamos a ver a continuación como construiríamos un `DataFrame` con datos de los integrantes de la selección Española de Fútbol:

# %%
selecciónEspañola = pd.DataFrame(
    {
        'nombre': ['Casillas', 'Ramos', 'Pique', 'Puyol', 'Capdevila', 'Xabi Alonso', 'Busquets', 'Xavi Hernandez',
                 'Pedrito', 'Iniesta', 'Villa'],
        'posición': ['Portero', 'Lateral Derecho', 'Defensa central', 'Defensa central', 'Lateral Izquierdo', 'Mediocampista defensivo',
                        'Mediocampista defensivo', 'Mediocampista', 'Extremo izquierdo', 'Extremo derecho', 'Delantero central'],
        'equipo': ['Real Madrid', 'Real Madrid', 'FC Barcelona', 'FC Barcelona', 'Villareal', 'Real Madrid',
                 'FC Barcelona', 'FC Barcelona', 'FC Barcelona', 'FC Barcelona', 'FC Barcelona']
    }, columns=['nombre', 'posición', 'equipo'], index=[1, 15, 3, 5, 11, 14, 16, 8, 18, 6, 7]
)
selecciónEspañola
# Out:
#             nombre                 posición        equipo
# 1         Casillas                  Portero   Real Madrid
# 15           Ramos          Lateral Derecho   Real Madrid
# 3            Pique          Defensa central  FC Barcelona
# 5            Puyol          Defensa central  FC Barcelona
# 11       Capdevila        Lateral Izquierdo     Villareal
# 14     Xabi Alonso  Mediocampista defensivo   Real Madrid
# 16        Busquets  Mediocampista defensivo  FC Barcelona
# 8   Xavi Hernandez            Mediocampista  FC Barcelona
# 18         Pedrito        Extremo izquierdo  FC Barcelona
# 6          Iniesta          Extremo derecho  FC Barcelona
# 7            Villa        Delantero central  FC Barcelona

# %% [markdown]
#  Como resultado tenemos una estructura de dato similar a la de una tabla de una base de datos relacional o de un documento excel o csv. Con esta estructura de datos se pueden hacer muchas operaciones como las que haríamos en una base de datos o en un documento excel.
#
# Por último vamos a ver como insertar un nuevo elemento en este `DataFrame`, que lo haríamos de la siguiente manera con el método `loc()`:

# %%
# Insertar un nuevo jugador
selecciónEspañola.loc[10] = ['Cesc', 'Delantero', 'Arsenal']
selecciónEspañola
# Out:
#             nombre                 posición        equipo
# 1         Casillas                  Portero   Real Madrid
# 15           Ramos          Lateral Derecho   Real Madrid
# 3            Pique          Defensa central  FC Barcelona
# 5            Puyol          Defensa central  FC Barcelona
# 11       Capdevila        Lateral Izquierdo     Villareal
# 14     Xabi Alonso  Mediocampista defensivo   Real Madrid
# 16        Busquets  Mediocampista defensivo  FC Barcelona
# 8   Xavi Hernandez            Mediocampista  FC Barcelona
# 18         Pedrito        Extremo izquierdo  FC Barcelona
# 6          Iniesta          Extremo derecho  FC Barcelona
# 7            Villa        Delantero central  FC Barcelona
# 10            Cesc                Delantero       Arsenal

# %% [markdown]
# ## Crear un `DataFrame` desde un archivo `.csv`

# %%
# Leer el archivo Income.csv y almacernarlo en un dataframe
df1 = pd.read_csv("../datos/Income_data.csv")
df1
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
# Visualizar el dataframe
df1.head()
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GEOID   5 non-null      object
#  1   State   5 non-null      object
#  2   2005    5 non-null      int64
#  3   2006    5 non-null      int64
#  4   2007    5 non-null      int64
#  5   2008    5 non-null      int64
#  6   2009    5 non-null      int64
#  7   2010    5 non-null      int64
#  8   2011    5 non-null      int64
#  9   2012    5 non-null      int64
#  10  2013    5 non-null      int64
# dtypes: int64(9), object(2)
# memory usage: 568.0+ bytes

# %%
df1.shape
# Out:
# (5, 11)

# %% [markdown]
# ## Crear un `DataFrame` desde una  `url`

# %%
# Leer un archivo desde internet
df2 = pd.read_csv("https://github.com/owid/covid-19-data/raw/master/public/data/owid-covid-data.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 2
#       1 # Leer un archivo desde internet
# ----> 2 df2 = pd.read_csv("https://github.com/owid/covid-19-data/raw/master/public/data/owid-covid-data.csv")
#
# File ~/mambaforge/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/mambaforge/lib/python3.9/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/mambaforge/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/mambaforge/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/mambaforge/lib/python3.9/site-packages/pandas/io/common.py:716, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     713     codecs.lookup_error(errors)
#     715 # open URLs
# --> 716 ioargs = _get_filepath_or_buffer(
#     717     path_or_buf,
#     718     encoding=encoding,
#     719     compression=compression,
#     720     mode=mode,
#     721     storage_options=storage_options,
#     722 )
#     724 handle = ioargs.filepath_or_buffer
#     725 handles: list[BaseBuffer]
#
# File ~/mambaforge/lib/python3.9/site-packages/pandas/io/common.py:373, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     370         if content_encoding == "gzip":
#     371             # Override compression based on Content-Encoding header
#     372             compression = {"method": "gzip"}
# --> 373         reader = BytesIO(req.read())
#     374     return IOArgs(
#     375         filepath_or_buffer=reader,
#     376         encoding=encoding,
#    (...)
#     379         mode=fsspec_mode,
#     380     )
#     382 if is_fsspec_url(filepath_or_buffer):
#
# File ~/mambaforge/lib/python3.9/http/client.py:476, in HTTPResponse.read(self, amt)
#     474 else:
#     475     try:
# --> 476         s = self._safe_read(self.length)
#     477     except IncompleteRead:
#     478         self._close_conn()
#
# File ~/mambaforge/lib/python3.9/http/client.py:626, in HTTPResponse._safe_read(self, amt)
#     624 s = []
#     625 while amt > 0:
# --> 626     chunk = self.fp.read(min(amt, MAXAMOUNT))
#     627     if not chunk:
#     628         raise IncompleteRead(b''.join(s), amt)
#
# File ~/mambaforge/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/mambaforge/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~/mambaforge/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Almacenar un `DataFrame` como un archivo `.csv`

# %%
df2.to_csv('../datos/covid-19.csv')

# %% [markdown]
# ## Inspeccionar un `DataFrame`
#
# - `df.head()` → retorna las 5 primeras filas. También le puedes pasar un entero como parámetro y te devolverá esa cantidad de primeras filas.
# - `df.tail()` → retorna las últimas 5 filas del dataset.
# - `df.sample()` → es parecido a los 2 anteriores, pero este tomará muestras al azar del `DataFrame`.
# - `df.shape` → retorna las filas y columnas que tiene el DataFrame.
# - `df.size` → multiplica las filas y columnas y te da el total de datos del `DataFrame`.
# - `df.info()` → información sobre la cuenta de valores no nulos, el tipo de dato de cada columna (recuerda que solo puede haber un único tipo de dato por columna) y el uso de memoria. Cuando estés procesando los datos, será un gran aliado.
# - `df.describe()` → Calcula algunas estadísticas descriptivas para cada columna.

# %%
covid_19 = pd.read_csv('../datos/covid-19.csv')
covid_19.head()
# Out:
#    Unnamed: 0 iso_code continent     location        date  total_cases  \
# 0           0      AFG      Asia  Afghanistan  2020-01-03          NaN
# 1           1      AFG      Asia  Afghanistan  2020-01-04          NaN
# 2           2      AFG      Asia  Afghanistan  2020-01-05          NaN
# 3           3      AFG      Asia  Afghanistan  2020-01-06          NaN
# 4           4      AFG      Asia  Afghanistan  2020-01-07          NaN
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  male_smokers  \
# 0        0.0                 NaN           NaN         0.0  ...           NaN
# 1        0.0                 NaN           NaN         0.0  ...           NaN
# 2        0.0                 NaN           NaN         0.0  ...           NaN
# 3        0.0                 NaN           NaN         0.0  ...           NaN
# 4        0.0                 NaN           NaN         0.0  ...           NaN
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                  37.746                         0.5            64.83
# 1                  37.746                         0.5            64.83
# 2                  37.746                         0.5            64.83
# 3                  37.746                         0.5            64.83
# 4                  37.746                         0.5            64.83
#
#    human_development_index  population  excess_mortality_cumulative_absolute  \
# 0                    0.511  41128772.0                                   NaN
# 1                    0.511  41128772.0                                   NaN
# 2                    0.511  41128772.0                                   NaN
# 3                    0.511  41128772.0                                   NaN
# 4                    0.511  41128772.0                                   NaN
#
#    excess_mortality_cumulative  excess_mortality  \
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4                          NaN               NaN
#
#    excess_mortality_cumulative_per_million
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 68 columns]

# %%
covid_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320309 entries, 0 to 320308
# Data columns (total 68 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   Unnamed: 0                                  320309 non-null  int64
#  1   iso_code                                    320309 non-null  object
#  2   continent                                   305073 non-null  object
#  3   location                                    320309 non-null  object
#  4   date                                        320309 non-null  object
#  5   total_cases                                 287547 non-null  float64
#  6   new_cases                                   311310 non-null  float64
#  7   new_cases_smoothed                          310046 non-null  float64
#  8   total_deaths                                269083 non-null  float64
#  9   new_deaths                                  311356 non-null  float64
#  10  new_deaths_smoothed                         310126 non-null  float64
#  11  total_cases_per_million                     287547 non-null  float64
#  12  new_cases_per_million                       311310 non-null  float64
#  13  new_cases_smoothed_per_million              310046 non-null  float64
#  14  total_deaths_per_million                    269083 non-null  float64
#  15  new_deaths_per_million                      311356 non-null  float64
#  16  new_deaths_smoothed_per_million             310126 non-null  float64
#  17  reproduction_rate                           184817 non-null  float64
#  18  icu_patients                                36686 non-null   float64
#  19  icu_patients_per_million                    36686 non-null   float64
#  20  hosp_patients                               37492 non-null   float64
#  21  hosp_patients_per_million                   37492 non-null   float64
#  22  weekly_icu_admissions                       9693 non-null    float64
#  23  weekly_icu_admissions_per_million           9693 non-null    float64
#  24  weekly_hosp_admissions                      22331 non-null   float64
#  25  weekly_hosp_admissions_per_million          22331 non-null   float64
#  26  total_tests                                 79387 non-null   float64
#  27  new_tests                                   75403 non-null   float64
#  28  total_tests_per_thousand                    79387 non-null   float64
#  29  new_tests_per_thousand                      75403 non-null   float64
#  30  new_tests_smoothed                          103965 non-null  float64
#  31  new_tests_smoothed_per_thousand             103965 non-null  float64
#  32  positive_rate                               95927 non-null   float64
#  33  tests_per_case                              94348 non-null   float64
#  34  tests_units                                 106788 non-null  object
#  35  total_vaccinations                          76262 non-null   float64
#  36  people_vaccinated                           73029 non-null   float64
#  37  people_fully_vaccinated                     69556 non-null   float64
#  38  total_boosters                              44763 non-null   float64
#  39  new_vaccinations                            62761 non-null   float64
#  40  new_vaccinations_smoothed                   172133 non-null  float64
#  41  total_vaccinations_per_hundred              76262 non-null   float64
#  42  people_vaccinated_per_hundred               73029 non-null   float64
#  43  people_fully_vaccinated_per_hundred         69556 non-null   float64
#  44  total_boosters_per_hundred                  44763 non-null   float64
#  45  new_vaccinations_smoothed_per_million       172133 non-null  float64
#  46  new_people_vaccinated_smoothed              171962 non-null  float64
#  47  new_people_vaccinated_smoothed_per_hundred  171962 non-null  float64
#  48  stringency_index                            197651 non-null  float64
#  49  population_density                          271787 non-null  float64
#  50  median_age                                  252782 non-null  float64
#  51  aged_65_older                               243935 non-null  float64
#  52  aged_70_older                               250250 non-null  float64
#  53  gdp_per_capita                              247730 non-null  float64
#  54  extreme_poverty                             159591 non-null  float64
#  55  cardiovasc_death_rate                       248217 non-null  float64
#  56  diabetes_prevalence                         260864 non-null  float64
#  57  female_smokers                              186199 non-null  float64
#  58  male_smokers                                183663 non-null  float64
#  59  handwashing_facilities                      121567 non-null  float64
#  60  hospital_beds_per_thousand                  219115 non-null  float64
#  61  life_expectancy                             294560 non-null  float64
#  62  human_development_index                     240606 non-null  float64
#  63  population                                  320309 non-null  float64
#  64  excess_mortality_cumulative_absolute        11117 non-null   float64
#  65  excess_mortality_cumulative                 11117 non-null   float64
#  66  excess_mortality                            11117 non-null   float64
#  67  excess_mortality_cumulative_per_million     11117 non-null   float64
# dtypes: float64(62), int64(1), object(5)
# memory usage: 166.2+ MB

# %%
covid_19.shape
# Out:
# (320309, 68)

# %% [markdown]
# Antes de extraer datos del dataframe, sería una buena práctica asignar una columna con valores únicos como el índice del dataframe. La columna `State` sería una buena opción:

# %%
df2 = df1.set_index('State')
df2
# Out:
#                 GEOID   2005   2006   2007   2008   2009   2010   2011   2012  \
# State
# Alabama     04000US01  37150  37952  42212  44476  39980  40933  42590  43464
# Alaska      04000US02  55891  56418  62993  63989  61604  57848  57431  63648
# Arizona     04000US04  45245  46657  47215  46914  45739  46896  48621  47044
# Arkansas    04000US05  36658  37057  40795  39586  36538  38587  41302  39018
# California  04000US06  51755  55319  55734  57014  56134  54283  53367  57020
#
#              2013
# State
# Alabama     41381
# Alaska      61137
# Arizona     50602
# Arkansas    39919
# California  57528

# %% [markdown]
# Ahora, vamos a extraer un subconjunto del dataframe. Aquí está la regla de sintaxis general para subconjunto de porciones de un dataframe:
#
#     df2.loc[startrow:endrow,startcolumn:endcolumn]

# %% [markdown]
# Extraer los valores para las filas desde Alaska hasta Arkansas para los años 2005 a 2007:|

# %%
df2.loc["Alaska":"Arkansas","2005":"2007"]
# Out:
#            2005   2006   2007
# State
# Alaska    55891  56418  62993
# Arizona   45245  46657  47215
# Arkansas  36658  37057  40795

# %% [markdown]
# Extraer una columna:

# %%
df2.loc[: , "2005"]
# Out:
# State
# Alabama       37150
# Alaska        55891
# Arizona       45245
# Arkansas      36658
# California    51755
# Name: 2005, dtype: int64

# %% [markdown]
# Tenga en cuenta que cuando extrae una sola fila o columna, obtiene un objeto unidimensional como salida. Eso se llama una Series en pandas. Los valores de la izquierda son sólo etiquetas tomadas del índice del dataframe. Por otro lado, cuando extrajimos porciones de un pandas dataframe como lo hicimos antes, obtuvimos un tipo bidimensional de objeto DataFrame.
#
# Por lo tanto, la fórmula para extraer una columna sigue siendo la misma, pero esta vez no pasamos ningún nombre de índice antes y después del primer colon. Eso le dice a Python que incluya todas las filas. Y pasamos sólo un nombre de columna.
#
# Para extraer sólo una fila se haría a la inversa:

# %%
df2.loc["California", : ]
# Out:
# GEOID    04000US06
# 2005         51755
# 2006         55319
# 2007         55734
# 2008         57014
# 2009         56134
# 2010         54283
# 2011         53367
# 2012         57020
# 2013         57528
# Name: California, dtype: object

# %% [markdown]
# Para extraer una celda:

# %%
df2.loc["California","2013"]
# Out:
# 57528

# %% [markdown]
# Se pueden aplicar métodos a los subconjuntos. Por ejemplo la media de la columna 2005:

# %%
df2.loc[:,"2005"].mean()
# Out:
# 45339.8

# %% [markdown]
# ### Indexación basada en la posición
#
# A veces, no se tienen etiquetas de fila o columna. En tal caso usted tendrá que confiar en indexación basada en la posición, la cual que se implementa con `iloc` en lugar de `loc`

# %%
df2.iloc[0:3,0:4]
# Out:
#              GEOID   2005   2006   2007
# State
# Alabama  04000US01  37150  37952  42212
# Alaska   04000US02  55891  56418  62993
# Arizona  04000US04  45245  46657  47215

# %% [markdown]
# Tenga en cuenta que cuando se utilizó indexación basada en etiquetas tanto el inicio y el final de las etiquetas se incluyeron en el subconjunto. Con el rebanado basado en posición, sólo se incluye el índice de inicio. Así, en este caso Alabama tenía un índice de 0, Alaska 1, y Arizona 2. Lo mismo ocurre con las columnas.

# %% [markdown]
# ### Funciones de análisis de datos Pandas
#
# Veamos ahora qué métodos de análisis de datos podemos aplicar a los dataframes de pandas.
#
# - `.sum()` → suma todos los valores de una columna.
# - `.mean()` → promedio de los valores de una columna.
# - `.max()` → valor máximo de una columna.
# - `.min()` → valor mínimo de una columna.
# - `.cumsum()` → en cada fila va poniendo la suma acumulada de una columna.
# - `.cummax()` → en cada fila va poniendo el valor máximo encontrado en orden de una columna.
# - `.value_counts(sort=True)` → cuenta los distintos valores que existen en una columna (muy útil para contar categorías) y los ordena descendientemente.
# - `.drop_duplicates(subset='col_name')` → elimina duplicados en una columna.
#
# Por ejemplo, aquí es cómo se aplica el método `mean` al dataframe en el que hemos estado trabajando

# %%
df2.iloc[:,1:].mean()
# Out:
# 2005    45339.8
# 2006    46680.6
# 2007    49789.8
# 2008    50395.8
# 2009    47999.0
# 2010    47709.4
# 2011    48662.2
# 2012    50038.8
# 2013    50113.4
# dtype: float64

# %% [markdown]
# Puede obtener una lista de los métodos disponibles para los dataframe utilizando la función `dir` de Python:

# %%
len(dir(pd.DataFrame))
# Out:
# 427

# %% [markdown]
# Y puede obtener la descripción de cada método mediante `help`:

# %%
help(pd.DataFrame.max)
# Out:
# Help on function max in module pandas.core.generic:
#
# max(self, axis: 'AxisInt | None' = 0, skipna: 'bool_t' = True, numeric_only: 'bool_t' = False, **kwargs)
#     Return the maximum of the values over the requested axis.
#
#     If you want the *index* of the maximum, use ``idxmax``. This is the equivalent of the ``numpy.ndarray`` method ``argmax``.
#
#     Parameters
#     ----------
#     axis : {index (0), columns (1)}
#         Axis for the function to be applied on.
#         For `Series` this parameter is unused and defaults to 0.
#
#         For DataFrames, specifying ``axis=None`` will apply the aggregation
#         across both axes.
#
#         .. versionadded:: 2.0.0
#
#     skipna : bool, default True
#         Exclude NA/null values when computing the result.
#     numeric_only : bool, default False
#         Include only float, int, boolean columns. Not implemented for Series.
#
#     **kwargs
#         Additional keyword arguments to be passed to the function.
#
#     Returns
#     -------
#     Series or scalar
#
#     See Also
#     --------
#     Series.sum : Return the sum.
#     Series.min : Return the minimum.
#     Series.max : Return the maximum.
#     Series.idxmin : Return the index of the minimum.
#     Series.idxmax : Return the index of the maximum.
#     DataFrame.sum : Return the sum over the requested axis.
#     DataFrame.min : Return the minimum over the requested axis.
#     DataFrame.max : Return the maximum over the requested axis.
#     DataFrame.idxmin : Return the index of the minimum over the requested axis.
#     DataFrame.idxmax : Return the index of the maximum over the requested axis.
#
#     Examples
#     --------
#     >>> idx = pd.MultiIndex.from_arrays([
#     ...     ['warm', 'warm', 'cold', 'cold'],
#     ...     ['dog', 'falcon', 'fish', 'spider']],
#     ...     names=['blooded', 'animal'])
#     >>> s = pd.Series([4, 2, 0, 8], name='legs', index=idx)
#     >>> s
#     blooded  animal
#     warm     dog       4
#              falcon    2
#     cold     fish      0
#              spider    8
#     Name: legs, dtype: int64
#
#     >>> s.max()
#     8

# %% [markdown]
# También puede aplicar métodos a las columnas del dataframe

# %%
df2.loc[:,"2005"].mean()
# Out:
# 45339.8

# %% [markdown]
# Tenga en cuenta que en este caso no está aplicando el método de media a un pandas dataframe, sino a un objeto series de pandas:

# %%
type(df2.loc[:,"2005"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Añadir columnas a un DataFrame es bastante sencillo:

# %%
# Añadir una nueva columna con etiqueta "2014" con los valores de la lista
df2["2014"] = [41325,65789,49002,40489,58934] 
df2
# Out:
#                 GEOID   2005   2006   2007   2008   2009   2010   2011   2012  \
# State
# Alabama     04000US01  37150  37952  42212  44476  39980  40933  42590  43464
# Alaska      04000US02  55891  56418  62993  63989  61604  57848  57431  63648
# Arizona     04000US04  45245  46657  47215  46914  45739  46896  48621  47044
# Arkansas    04000US05  36658  37057  40795  39586  36538  38587  41302  39018
# California  04000US06  51755  55319  55734  57014  56134  54283  53367  57020
#
#              2013   2014
# State
# Alabama     41381  41325
# Alaska      61137  65789
# Arizona     50602  49002
# Arkansas    39919  40489
# California  57528  58934

# %%
# Anadir una nueva columna con el ingreso medio de cada estado
df2["Mean"] = df2.iloc[:, 1:].mean(axis=1)
df2
# Out:
#                 GEOID   2005   2006   2007   2008   2009   2010   2011   2012  \
# State
# Alabama     04000US01  37150  37952  42212  44476  39980  40933  42590  43464
# Alaska      04000US02  55891  56418  62993  63989  61604  57848  57431  63648
# Arizona     04000US04  45245  46657  47215  46914  45739  46896  48621  47044
# Arkansas    04000US05  36658  37057  40795  39586  36538  38587  41302  39018
# California  04000US06  51755  55319  55734  57014  56134  54283  53367  57020
#
#              2013   2014     Mean
# State
# Alabama     41381  41325  41146.3
# Alaska      61137  65789  60674.8
# Arizona     50602  49002  47393.5
# Arkansas    39919  40489  38994.9
# California  57528  58934  55708.8

# %% [markdown]
# El parámetro `axis` le indica a Python que calcule la media a lo largo del eje 1, que significa a lo largo de las columnas. El eje puesto a 0 iría a lo largo de las filas. Vamos a ver cómo calcular la media de cada año y agregarlos como una nueva fila

# %%
# Añadir nueva fila con el ingreso medio por año
df2.loc["Media"] = df2.iloc[:,1:].mean(axis=0)
df2
# Out:
#                 GEOID     2005     2006     2007     2008     2009     2010  \
# State
# Alabama     04000US01  37150.0  37952.0  42212.0  44476.0  39980.0  40933.0
# Alaska      04000US02  55891.0  56418.0  62993.0  63989.0  61604.0  57848.0
# Arizona     04000US04  45245.0  46657.0  47215.0  46914.0  45739.0  46896.0
# Arkansas    04000US05  36658.0  37057.0  40795.0  39586.0  36538.0  38587.0
# California  04000US06  51755.0  55319.0  55734.0  57014.0  56134.0  54283.0
# Media             NaN  45339.8  46680.6  49789.8  50395.8  47999.0  47709.4
#
#                2011     2012     2013     2014      Mean
# State
# Alabama     42590.0  43464.0  41381.0  41325.0  41146.30
# Alaska      57431.0  63648.0  61137.0  65789.0  60674.80
# Arizona     48621.0  47044.0  50602.0  49002.0  47393.50
# Arkansas    41302.0  39018.0  39919.0  40489.0  38994.90
# California  53367.0  57020.0  57528.0  58934.0  55708.80
# Media       48662.2  50038.8  50113.4  51107.8  48783.66

# %% [markdown]
# ## Eliminación de Columnas

# %%
covid_19.head()
# Out:
#    Unnamed: 0 iso_code continent     location        date  total_cases  \
# 0           0      AFG      Asia  Afghanistan  2020-01-03          NaN
# 1           1      AFG      Asia  Afghanistan  2020-01-04          NaN
# 2           2      AFG      Asia  Afghanistan  2020-01-05          NaN
# 3           3      AFG      Asia  Afghanistan  2020-01-06          NaN
# 4           4      AFG      Asia  Afghanistan  2020-01-07          NaN
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  male_smokers  \
# 0        0.0                 NaN           NaN         0.0  ...           NaN
# 1        0.0                 NaN           NaN         0.0  ...           NaN
# 2        0.0                 NaN           NaN         0.0  ...           NaN
# 3        0.0                 NaN           NaN         0.0  ...           NaN
# 4        0.0                 NaN           NaN         0.0  ...           NaN
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                  37.746                         0.5            64.83
# 1                  37.746                         0.5            64.83
# 2                  37.746                         0.5            64.83
# 3                  37.746                         0.5            64.83
# 4                  37.746                         0.5            64.83
#
#    human_development_index  population  excess_mortality_cumulative_absolute  \
# 0                    0.511  41128772.0                                   NaN
# 1                    0.511  41128772.0                                   NaN
# 2                    0.511  41128772.0                                   NaN
# 3                    0.511  41128772.0                                   NaN
# 4                    0.511  41128772.0                                   NaN
#
#    excess_mortality_cumulative  excess_mortality  \
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4                          NaN               NaN
#
#    excess_mortality_cumulative_per_million
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 68 columns]

# %%
covid_19.drop(columns=['Unnamed: 0'], inplace=True)

# %%
covid_19
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 320304      ZWE    Africa     Zimbabwe  2023-06-17     265289.0        0.0
# 320305      ZWE    Africa     Zimbabwe  2023-06-18     265289.0        0.0
# 320306      ZWE    Africa     Zimbabwe  2023-06-19     265413.0      124.0
# 320307      ZWE    Africa     Zimbabwe  2023-06-20     265413.0        NaN
# 320308      ZWE    Africa     Zimbabwe  2023-06-21     265413.0        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 320304              18.286        5702.0         0.0                1.000
# 320305              18.286        5702.0         0.0                1.000
# 320306              17.714        5707.0         5.0                0.714
# 320307                 NaN        5707.0         0.0                0.714
# 320308                 NaN        5707.0         0.0                0.714
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 320304  ...          30.7                  36.791                         1.7
# 320305  ...          30.7                  36.791                         1.7
# 320306  ...          30.7                  36.791                         1.7
# 320307  ...          30.7                  36.791                         1.7
# 320308  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 320304            61.49                    0.571  16320539.0
# 320305            61.49                    0.571  16320539.0
# 320306            61.49                    0.571  16320539.0
# 320307            61.49                    0.571  16320539.0
# 320308            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 320304                                   NaN                          NaN
# 320305                                   NaN                          NaN
# 320306                                   NaN                          NaN
# 320307                                   NaN                          NaN
# 320308                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 320304               NaN                                      NaN
# 320305               NaN                                      NaN
# 320306               NaN                                      NaN
# 320307               NaN                                      NaN
# 320308               NaN                                      NaN
#
# [320309 rows x 67 columns]

# %% [markdown]
# ## Crear un nuevo `DataFrame` con columnas de `covid_19`

# %%
columnas = ['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths']
covid_19_casos_muertes = covid_19[columnas].copy()

# %%
covid_19_casos_muertes.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    total_deaths  new_deaths
# 0           NaN         0.0
# 1           NaN         0.0
# 2           NaN         0.0
# 3           NaN         0.0
# 4           NaN         0.0

# %%
covid_19_casos_muertes.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 320304      ZWE    Africa  Zimbabwe  2023-06-17     265289.0        0.0
# 320305      ZWE    Africa  Zimbabwe  2023-06-18     265289.0        0.0
# 320306      ZWE    Africa  Zimbabwe  2023-06-19     265413.0      124.0
# 320307      ZWE    Africa  Zimbabwe  2023-06-20     265413.0        NaN
# 320308      ZWE    Africa  Zimbabwe  2023-06-21     265413.0        NaN
#
#         total_deaths  new_deaths
# 320304        5702.0         0.0
# 320305        5702.0         0.0
# 320306        5707.0         5.0
# 320307        5707.0         0.0
# 320308        5707.0         0.0

# %%
covid_19_casos_muertes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320309 entries, 0 to 320308
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   iso_code      320309 non-null  object
#  1   continent     305073 non-null  object
#  2   location      320309 non-null  object
#  3   date          320309 non-null  object
#  4   total_cases   287547 non-null  float64
#  5   new_cases     311310 non-null  float64
#  6   total_deaths  269083 non-null  float64
#  7   new_deaths    311356 non-null  float64
# dtypes: float64(4), object(4)
# memory usage: 19.6+ MB

# %% [markdown]
# ### Convertir columna `date` del tipo `object` a tipo `datetime`

# %%
covid_19_casos_muertes['date'] = pd.to_datetime(covid_19_casos_muertes['date'], infer_datetime_format=True)
# Out:
# /var/folders/x4/__tc8h0d0rs9324_8_zvtysh0000gn/T/ipykernel_5340/1514626898.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   covid_19_casos_muertes['date'] = pd.to_datetime(covid_19_casos_muertes['date'], infer_datetime_format=True)

# %%
covid_19_casos_muertes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320309 entries, 0 to 320308
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   iso_code      320309 non-null  object
#  1   continent     305073 non-null  object
#  2   location      320309 non-null  object
#  3   date          320309 non-null  datetime64[ns]
#  4   total_cases   287547 non-null  float64
#  5   new_cases     311310 non-null  float64
#  6   total_deaths  269083 non-null  float64
#  7   new_deaths    311356 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 19.6+ MB

# %% [markdown]
# ### Tratamiento de los valores `NaN`

# %%
covid_19_casos_muertes[pd.isna(covid_19_casos_muertes.continent)]
# Out:
# Empty DataFrame
# Columns: [iso_code, continent, location, date, total_cases, new_cases, total_deaths, new_deaths]
# Index: []

# %%
covid_19_casos_muertes = covid_19_casos_muertes[covid_19_casos_muertes['continent'].notna()]

# %%
covid_19_casos_muertes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 305073 entries, 0 to 320308
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   iso_code      305073 non-null  object
#  1   continent     305073 non-null  object
#  2   location      305073 non-null  object
#  3   date          305073 non-null  datetime64[ns]
#  4   total_cases   272458 non-null  float64
#  5   new_cases     296118 non-null  float64
#  6   total_deaths  254156 non-null  float64
#  7   new_deaths    296164 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 20.9+ MB

# %%
covid_19_casos_muertes.fillna(0, inplace=True)

# %%
covid_19_casos_muertes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 305073 entries, 0 to 320308
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   iso_code      305073 non-null  object
#  1   continent     305073 non-null  object
#  2   location      305073 non-null  object
#  3   date          305073 non-null  datetime64[ns]
#  4   total_cases   305073 non-null  float64
#  5   new_cases     305073 non-null  float64
#  6   total_deaths  305073 non-null  float64
#  7   new_deaths    305073 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 20.9+ MB

# %% [markdown]
# ### Agrupar datos

# %%
covid_19_casos_muertes.groupby(['continent'])['total_deaths'].max()
# Out:
# continent
# Africa            102595.0
# Asia              531896.0
# Europe            399436.0
# North America    1127152.0
# Oceania            21510.0
# South America     703399.0
# Name: total_deaths, dtype: float64

# %%
covid_19_casos_muertes.groupby(['continent', 'location'])['new_cases'].agg(['mean', 'sum'])
# Out:
#                                    mean        sum
# continent     location
# Africa        Algeria        214.729068   271847.0
#               Angola          83.241706   105384.0
#               Benin           22.127962    28014.0
#               Botswana       260.651659   329985.0
#               Burkina Faso    17.421801    22056.0
# ...                                 ...        ...
# South America Paraguay       581.168246   735759.0
#               Peru          3549.687402  4508103.0
#               Suriname        65.215640    82563.0
#               Uruguay        817.311566  1038803.0
#               Venezuela      436.567930   552695.0
#
# [243 rows x 2 columns]

# %%
casos_venezuela = covid_19_casos_muertes[covid_19_casos_muertes.location == 'Venezuela']['total_cases']
muertes_venezuela = covid_19_casos_muertes[covid_19_casos_muertes.location == 'Venezuela']['total_deaths']
plt.plot(casos_venezuela)
plt.plot(muertes_venezuela)

# %%
new_df = covid_19_casos_muertes.groupby(['continent', 'location'])['new_deaths'].agg(['mean', 'sum']).reset_index()

# %%
new_df
# Out:
#          continent      location        mean       sum
# 0           Africa       Algeria    5.435229    6881.0
# 1           Africa        Angola    1.527646    1934.0
# 2           Africa         Benin    0.128752     163.0
# 3           Africa      Botswana    2.209321    2797.0
# 4           Africa  Burkina Faso    0.312796     396.0
# ..             ...           ...         ...       ...
# 238  South America      Paraguay   15.766983   19961.0
# 239  South America          Peru  173.852756  220793.0
# 240  South America      Suriname    1.110585    1406.0
# 241  South America       Uruguay    6.007081    7635.0
# 242  South America     Venezuela    4.625592    5856.0
#
# [243 rows x 4 columns]

# %%
sur_america = new_df[new_df.continent == 'South America']

# %%
sur_america
# Out:
#          continent          location        mean       sum
# 229  South America         Argentina  102.572327  130472.0
# 230  South America           Bolivia   17.683254   22387.0
# 231  South America            Brazil  555.607425  703399.0
# 232  South America             Chile   51.370166   65086.0
# 233  South America          Colombia  112.791469  142794.0
# 234  South America           Ecuador   28.451027   36019.0
# 235  South America  Falkland Islands    0.000000       0.0
# 236  South America     French Guiana    0.326224     413.0
# 237  South America            Guyana    1.025276    1298.0
# 238  South America          Paraguay   15.766983   19961.0
# 239  South America              Peru  173.852756  220793.0
# 240  South America          Suriname    1.110585    1406.0
# 241  South America           Uruguay    6.007081    7635.0
# 242  South America         Venezuela    4.625592    5856.0

# %%
sur_america.sort_values('sum', ascending=False)
# Out:
#          continent          location        mean       sum
# 231  South America            Brazil  555.607425  703399.0
# 239  South America              Peru  173.852756  220793.0
# 233  South America          Colombia  112.791469  142794.0
# 229  South America         Argentina  102.572327  130472.0
# 232  South America             Chile   51.370166   65086.0
# 234  South America           Ecuador   28.451027   36019.0
# 230  South America           Bolivia   17.683254   22387.0
# 238  South America          Paraguay   15.766983   19961.0
# 241  South America           Uruguay    6.007081    7635.0
# 242  South America         Venezuela    4.625592    5856.0
# 240  South America          Suriname    1.110585    1406.0
# 237  South America            Guyana    1.025276    1298.0
# 236  South America     French Guiana    0.326224     413.0
# 235  South America  Falkland Islands    0.000000       0.0
